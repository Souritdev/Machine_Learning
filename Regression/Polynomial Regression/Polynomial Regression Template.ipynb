# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Importing Data Set

# %%
data_set = pd.read_csv("RBC in Humans.csv")
X = data_set.iloc[:, :-1].values
y = data_set.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_reg = PolynomialFeatures(degree=6)
X_poly = polynomial_reg.fit_transform(X)

linear_reg_2 = LinearRegression()
linear_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X , y , color = 'Red')
plt.plot(X, linear_reg.predict(X), color= 'Blue')
plt.title('RBC - Linear_Regression')
plt.xlabel('Age')
plt.ylabel('RBC Count')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
reshaped = X_grid.reshape(len(X_grid), 1)


plt.scatter(X , y , color = 'Red')
plt.plot(reshaped, linear_reg_2.predict(polynomial_reg.transform(reshaped)), color= 'Blue')
plt.title('RBC - PolyNomial_Regression')
plt.xlabel('Age')
plt.ylabel('RBC Count')
plt.show()
# Out:
# C:\Users\souri\AppData\Local\Temp\ipykernel_7868\903627146.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
linear_reg.predict([[10]])
# Out:
# array([1655.24645563])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
linear_reg_2.predict(polynomial_reg.transform([[10]]))
# Out:
# array([1450.5286675])
